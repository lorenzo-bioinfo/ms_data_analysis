# %%
import pandas as pd
pd.set_option('display.max_rows', None)
df = pd.read_csv('ctrl_vs_euro_bh.tsv', sep = '\t')
print(df)
# Out:
#      Unnamed: 0      snp_id  samp_dim     Chi-stat          p-val  \
# 0             8   rs4869676        51          inf   0.000000e+00
# 1           101  rs16845626        46  1140.718830  1.977213e-248
# 2            55   rs1295685        47   161.200045   9.905011e-36
# 3            26  rs10932201        47   118.104536   2.259050e-26
# 4            94  rs12377632        43    71.861976   2.485251e-16
# 5            65   rs2295633        47    33.063021   6.613880e-08
# 6             0    rs222747        65    20.735943   3.142297e-05
# 7           100  rs11651708        48    18.065307   1.194451e-04
# 8             4   rs1805247        51    16.584107   2.504996e-04
# 9            86   rs9912468        48    14.043073   8.924530e-04
# 10           76    rs466448        47    12.573255   1.861026e-03
# 11           13   rs4649124        48    12.376717   2.053195e-03
# 12           78    rs475007        48    11.118421   3.851816e-03
# ...
