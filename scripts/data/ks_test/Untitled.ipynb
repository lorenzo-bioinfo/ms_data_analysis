# %%
import pandas as pd

df = pd.read_csv('RR_bh_corr.tsv', sep = '\t')
df
# Out:
#        cyt   ks_stat   p_value  ctrl_median  patient_median  N_ct  N_pat  \
# 0     CCL3  0.391304  0.000000        0.375          0.6575   138    230
# 1     CCL4  0.286957  0.000001        3.365          4.4600   138    230
# 2     CCL2  0.275362  0.000003      153.195        123.2200   138    230
# 3     CSF3  0.252174  0.000027       12.590         22.3100   138    230
# 4      IL2  0.224638  0.000275        0.000          0.0950   138    230
# 5     IFNG  0.218841  0.000432        2.440          1.7150   138    230
# 6      IL6  0.217391  0.000483        0.465          1.2600   138    230
# 7     CSF2  0.205797  0.001147        0.000          0.0000   138    230
# 8    VEGFA  0.176812  0.008061        1.735         10.0800   138    230
# 9   CXCL10  0.169565  0.012525      436.595        560.3700   138    230
# 10   IL1RN  0.159420  0.022497       20.900         18.8650   138    230
# 11    IL10  0.157971  0.024388        1.440          1.8400   138    230
# ...

# %%
df3 = pd.read_csv('RR_bh_corr_clean.tsv', sep = '\t')
df3
# Out:
#        cyt   ks_stat   p_value  ctrl_median  patient_median  q_values
# 0     CCL3  0.411829  0.000000         0.36          0.6275  0.000000
# 1     CCL4  0.301422  0.000000         3.28          4.3000  0.000000
# 2     CCL2  0.290917  0.000001       148.04        119.2725  0.000009
# 3     CSF3  0.264864  0.000015        11.73         19.8900  0.000101
# 4      IL2  0.235836  0.000177         0.00          0.0000  0.000956
# 5     IFNG  0.231354  0.000249         2.37          1.6200  0.001120
# 6      IL6  0.228657  0.000291         0.41          1.1100  0.001122
# 7     CSF2  0.215736  0.000804         0.00          0.0000  0.002714
# 8    VEGFA  0.185727  0.005881         0.00          7.3225  0.017643
# 9   CXCL10  0.177463  0.009932       426.53        535.9850  0.026816
# 10   IL1RN  0.168359  0.016861        18.79         17.8350  0.041386
# 11    IL10  0.165698  0.019397         1.39          1.7800  0.043643
# ...

# %%
df2 = pd.read_csv('../../../../ms_analysis/scripts/data/ks_test/RR_bh_corr.tsv', sep = '\t')
df2
# Out:
#           cyt   ks_stat   p_value  ctrl_median  patient_median  q_values
# 0      MIP-1a  0.406821  0.000000         0.34           0.620  0.000000
# 1      MIP-1b  0.316918  0.000008         3.56           4.520  0.000108
# 2       MCP-1  0.300821  0.000026       155.16         121.650  0.000234
# 3        IL-2  0.272826  0.000195         0.00           0.030  0.001316
# 4       G-CSF  0.231978  0.002510        11.06          15.550  0.013554
# 5       IFN-g  0.230896  0.002670         2.48           1.810  0.012015
# 6        IL-6  0.229878  0.002821         0.28           1.050  0.010881
# 7      GM-CSF  0.216835  0.005792         0.00           0.000  0.019548
# 8       IL-17  0.213018  0.007072         0.19           0.480  0.021216
# 9       IL-10  0.194821  0.017731         1.62           2.040  0.047874
# 10  FGC_basic  0.191512  0.020681         0.20           1.210  0.050762
# 11      IL-12  0.185659  0.027222         0.06           0.190  0.061249
# ...
