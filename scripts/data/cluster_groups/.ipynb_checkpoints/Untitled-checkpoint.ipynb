# %%
import pandas as pd
pd.options.display.max_columns = 999
df_occ = pd.read_csv('occ_matrix.tsv', sep = '\t', header = 0, index_col = 0)
df_occ
# Out:
#         IL1B  IL2  IL4  IL5  IL6  IL7  CXCL8  IL10  IL12B  IL13  IL17A  CSF3  \
# IL1B       7    6    7    2    6    7      1     0      6     1      6     4
# IL2        6    7    6    2    7    6      1     1      7     0      7     4
# IL4        7    6    7    2    6    7      1     0      6     1      6     4
# IL5        2    2    2    7    2    2      3     3      2     1      2     3
# IL6        6    7    6    2    7    6      1     1      7     0      7     4
# IL7        7    6    7    2    6    7      1     0      6     1      6     4
# CXCL8      1    1    1    3    1    1      7     2      1     0      1     1
# IL10       0    1    0    3    1    0      2     7      1     4      1     1
# IL12B      6    7    6    2    7    6      1     1      7     0      7     4
# IL13       1    0    1    1    0    1      0     4      0     7      0     2
# IL17A      6    7    6    2    7    6      1     1      7     0      7     4
# ...

# %%
df_dist = pd.read_csv('dist_matrix.tsv', sep = '\t', header = 0, index_col = 0)
pippo = df_dist.describe()
df_dist
# Out:
#              IL1B        IL2        IL4        IL5        IL6        IL7  \
# IL1B     0.000000   6.285714   2.571429  11.142857   3.857143   3.285714
# IL2      6.285714   0.000000   7.142857   9.142857   6.428571   6.428571
# IL4      2.571429   7.142857   0.000000  12.285714   3.285714   3.571429
# IL5     11.142857   9.142857  12.285714   0.000000  10.428571  12.714286
# IL6      3.857143   6.428571   3.285714  10.428571   0.000000   2.857143
# IL7      3.285714   6.428571   3.571429  12.714286   2.857143   0.000000
# CXCL8   13.571429  10.714286  11.285714  10.428571  10.857143  12.285714
# IL10    10.428571   7.285714  11.285714   7.571429  12.000000  12.285714
# IL12B    6.142857   1.000000   6.714286   9.571429   5.714286   6.000000
# IL13    10.571429   6.285714  12.285714  11.428571  12.714286  11.285714
# IL17A    4.714286   4.714286   4.428571   9.857143   3.142857   5.142857
# CSF3    10.142857   9.571429   9.571429   8.428571   8.857143  10.857143
# ...

# %%
[IL1B, IL4, IL7, VEGFA]
[IL2, IL6, IL12B, IL17A, CSF2, FGF2, PDGFB, IL15]
[IL5, IL1RN]
[CXCL8, CXCL10]
[IL10, IL9, CCL5]
[IL13, TNF, CCL4, CCL11]
[CSF3, CCL3]
[IFNG, CCL2]

# %%
#gruppi a occhio da heatmap

[IL1B, IL4, IL7, VEGFA, IL2, IL6, IL12B, IL17A, CSF2, FGF2, PDGFB, IL15]
[IL5, IL1RN, CSF3, CCL3]
[IFNG, CCL2]
[TNF, CCL4]
[IL9, CCL5]
[CXCL10, CCL11, CXCL8]
[IL10, IL13]
